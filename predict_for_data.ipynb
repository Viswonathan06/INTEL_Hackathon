# %%
os.chdir("/Users/viswonathanmanoranjan/Documents/GitHub/INTEL_Hackathon")
import os, sys
sys.path.append('./Feature_Extraction')
sys.path.append('./oneAPI_Tensorflow')
os.chdir("./Feature_Extraction/")
from Extract_All_Data import get_training_file
os.chdir("../oneAPI_Tensorflow/")
from training_prediction import single_video_prediction, training
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 8
#       6 from Extract_All_Data import get_training_file
#       7 os.chdir("../oneAPI_Tensorflow/")
# ----> 8 from training_prediction import single_video_prediction, training
#
# File ~/Documents/GitHub/INTEL_Hackathon/oneAPI_Tensorflow/training_prediction.py:5
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 import autokeras as ak
#       6 import tensorflow as tf
#       7 from tensorflow.keras.models import load_model
#
# ModuleNotFoundError: No module named 'autokeras'

# %%
os.chdir("./Feature_Extraction/")
video_path = '../video/NAH.mov'
video_name = video_path.split('/')[-1].split('.')[0]
data = get_training_file(video_path)
# Out:
# Exists!!
# ../video/audio/NAH.wav
# MoviePy - Writing audio in ../video/audio/NAH.wav
# MoviePy - Done.
# [-0.01132202 -0.01635742 -0.01724243 ...  0.02627563  0.02618408
#   0.02584839] 44100
# (20, 503)
# NAH
# ../video/NAH.mov
# 0
# total 192
# 40 Extract_All_Data.ipynb
#  8 Extract_All_Data.py
#  0 FaceBoxes
#  0 Sim3DR
# 16 TDDFA.py
# 16 TDDFA_ONNX.py
#  0 __pycache__
#  0 bfm
#  8 build.sh
#  8 combine_features.py
#  0 configs
# 16 demo_video_smooth.py
#  0 docs
#  0 examples
#  8 extract_audio.py
#  0 models
#  8 parallel_run.py
# 24 readme.md
# 24 requirements.txt
#  8 run_facial_features.sh
#  8 speed_cpu.py
#  0 utils
#  0 weights
# ../features/aggregate_NAH_facial.csv
# aggregate_NAH_facial.csv
# ['aggregate', 'NAH', 'facial']
# ...

# %%
data.head()
# Out:
#   video      0_faci      1_faci      2_faci      3_faci     4_faci  \
# 0   NAH  587.974992  601.630844  621.355084  639.798314  662.76241
#
#        5_faci      6_faci      7_faci     8_faci  ...   50_audi   51_audi  \
# 0  697.633974  737.716062  794.169806  869.07416  ...  2.253911 -1.900061
#
#     52_audi   53_audi   54_audi   55_audi   56_audi   57_audi   58_audi  \
# 0  2.365227  0.464971 -2.884904 -1.314743  4.612043  0.919675 -6.080478
#
#     59_audi
# 0 -4.460571
#
# [1 rows x 469 columns]

# %%
prediction(data, video_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 prediction(data, video_name)
#
# NameError: name 'prediction' is not defined

# %%
for cols in test.columns:
    print(cols)
# Out:
# video
# 0_faci
# 1_faci
# 2_faci
# 3_faci
# 4_faci
# 5_faci
# 6_faci
# 7_faci
# 8_faci
# 9_faci
# 10_faci
# 11_faci
# 12_faci
# 13_faci
# 14_faci
# 15_faci
# 16_faci
# 17_faci
# 18_faci
# 19_faci
# 20_faci
# 21_faci
# 22_faci
# 23_faci
# 24_faci
# 25_faci
# 26_faci
# 27_faci
# 28_faci
# 29_faci
# 30_faci
# 31_faci
# 32_faci
# 33_faci
# 34_faci
# 35_faci
# 36_faci
# 37_faci
# 38_faci
# 39_faci
# 40_faci
# 41_faci
# 42_faci
# 43_faci
# 44_faci
# 45_faci
# 46_faci
# 47_faci
# 48_faci
# 49_faci
# 50_faci
# 51_faci
# 52_faci
# 53_faci
# 54_faci
# 55_faci
# 56_faci
# 57_faci
# 58_faci
# 59_faci
# 60_faci
# 61_faci
# 62_faci
# 63_faci
# 64_faci
# 65_faci
# 66_faci
# 67_faci
# 68_faci
# 69_faci
# 70_faci
# 71_faci
# 72_faci
# 73_faci
# 74_faci
# 75_faci
# 76_faci
# 77_faci
# 78_faci
# 79_faci
# 80_faci
# 81_faci
# 82_faci
# 83_faci
# 84_faci
# 85_faci
# 86_faci
# 87_faci
# 88_faci
# 89_faci
# 90_faci
# 91_faci
# 92_faci
# 93_faci
# 94_faci
# 95_faci
# 96_faci
# 97_faci
# 98_faci
# 99_faci
# ...

# %%
prediction()
